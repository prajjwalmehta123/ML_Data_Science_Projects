# %%
import pandas as pd 
df = pd.read_excel('neiss2019.xlsx')

# %%
df.head()
# Out:
#    CPSC_Case_Number Treatment_Date  Age  Sex  Race Other_Race  \
# 0         190103267     2019-01-01   81    1     0        NaN
# 1         190103268     2019-01-01   38    2     0        NaN
# 2         190103269     2019-01-01   94    1     0        NaN
# 3         190103270     2019-01-01   86    1     0        NaN
# 4         190103273     2019-01-01   87    2     0        NaN
#
#    Hispanic Origin  Body_Part  Diagnosis Other_Diagnosis  ...  \
# 0                0         79         57             NaN  ...
# 1                0         36         57             NaN  ...
# 2                0         75         62             NaN  ...
# 3                0         75         62             NaN  ...
# 4                0         32         53             NaN  ...
#
#    Fire_Involvement  Product_1 Product_2  Product_3  Alcohol involved  \
# 0                 0       1141         0          0                 0
# 1                 0       1842         0          0                 0
# ...

# %%
df.drop(columns = ['CPSC_Case_Number','Treatment_Date','Race','Other_Race','Hispanic Origin','Body_Part','Diagnosis','Other_Diagnosis','Body_Part_2','Diagnosis_2','Other_Diagnosis_2','Disposition','Location','Fire_Involvement','Alcohol involved','Drug involved','Stratum','PSU','Weight'])
g=df.groupby('Product_1')
g1 = g.get_group(464)
g1
# Out:
#         CPSC_Case_Number Treatment_Date  Age  Sex  Race  Other_Race  \
# 29             190103320     2019-01-01   20    1     0         NaN
# 54             190103384     2019-01-01   36    2     0         NaN
# 62             190103407     2019-01-01   62    1     0         NaN
# 88             190103460     2019-01-01   39    1     1         NaN
# 92             190104001     2019-01-01   23    1     1         NaN
# ...                  ...            ...  ...  ...   ...         ...
# 358520         200301258     2019-12-29   21    2     3  GUATEMALAN
# 358549         200301497     2019-12-02   37    1     0         NaN
# 358582         200301560     2019-12-16   74    2     0         NaN
# 358625         200304460     2019-12-30   40    1     4         NaN
# 358646         200304498     2019-12-30   32    1     1         NaN
#
#         Hispanic Origin  Body_Part  Diagnosis Other_Diagnosis  ...  \
# 29                    0         92         59             NaN  ...
# ...

# %%
#g1['Narrative_1_new']=g1['Narrative_1'].astype('|S')

# %%
key = ["Vegetables","veggies","Avacado",'Meat','Potato','Onion','Chicken','Apple','Melon','Bread','Cheese','Tomato','Fruit','Bagel','Orange','Lemon','Burger','Pepper','Steak','Lettuce','Carrot','Corn','Cucumber','Turkey','Mango','Lime','Ham','Cabbage','Sausage','Coconut','Pork','Brownies','Garlic','Cake','Bacon','Wine Bottle','Pizza','Sandwich','Oyesters','Pineapple','Muffin','Hot Dog','Cauliflower','Brussel Sprouts','Beef','Roast','Strawberries','Mushroom','Grape','Banana','Yams','Salmon','Kiwi','Kale','Ice cream','Herbs','Beets','Pie','Lobster','Greens','Grapefruit','Goose','Clams','Champagne','Broccoli','Yucca','Shrimp','Papusa','Duck']
key = [x.upper() for x in key]
a = dict.fromkeys(key,0)

# %%
for n in g1['Narrative_1']:
    for word in key:
        if(n.find(word)>=0):
            a[word]+=1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a['other'] = 0
for v in a:
    if(a.get(v)<15):
        a['other'] += a.get(v)
        a[v]=0
af = {x:y for x,y in a.items() if y!=0}

# %%
plt.figure(figsize=(15,15))
x=[float(v) for v in af.values()]
y=[k for k in af]
plt.pie(x,labels=y )
plt.show()
